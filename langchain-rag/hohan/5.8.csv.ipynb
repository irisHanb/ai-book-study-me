# %%
# %pip install langchain-experimental
# Out:
# Collecting langchain-experimental
#   Using cached langchain_experimental-0.0.57-py3-none-any.whl.metadata (2.1 kB)
# Collecting langchain<0.2.0,>=0.1.15 (from langchain-experimental)
#   Using cached langchain-0.1.15-py3-none-any.whl.metadata (13 kB)
# Collecting langchain-core<0.2.0,>=0.1.41 (from langchain-experimental)
#   Using cached langchain_core-0.1.41-py3-none-any.whl.metadata (5.9 kB)
# Collecting PyYAML>=5.3 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached SQLAlchemy-2.0.29-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached aiohttp-3.9.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.32 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached langchain_community-0.0.32-py3-none-any.whl.metadata (8.5 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Downloading langsmith-0.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2,>=1 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (114 kB)
# Collecting pydantic<3,>=1 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
# Collecting requests<3,>=2 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.41->langchain-experimental)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached marshmallow-3.21.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Downloading orjson-3.10.0-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.7 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic<3,>=1->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached pydantic_core-2.16.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from pydantic<3,>=1->langchain<0.2.0,>=0.1.15->langchain-experimental) (4.11.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain<0.2.0,>=0.1.15->langchain-experimental)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain_experimental-0.0.57-py3-none-any.whl (193 kB)
# Using cached langchain-0.1.15-py3-none-any.whl (814 kB)
# Using cached langchain_core-0.1.41-py3-none-any.whl (278 kB)
# Using cached aiohttp-3.9.3-cp311-cp311-macosx_11_0_arm64.whl (387 kB)
# Using cached dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_community-0.0.32-py3-none-any.whl (1.9 MB)
# Using cached langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Downloading langsmith-0.1.45-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.2/104.2 kB 6.3 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp311-cp311-macosx_11_0_arm64.whl (14.0 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached pydantic-2.6.4-py3-none-any.whl (394 kB)
# Using cached pydantic_core-2.16.3-cp311-cp311-macosx_11_0_arm64.whl (1.7 MB)
# Using cached PyYAML-6.0.1-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached SQLAlchemy-2.0.29-cp311-cp311-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_11_0_arm64.whl (118 kB)
# Using cached frozenlist-1.4.1-cp311-cp311-macosx_11_0_arm64.whl (53 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Using cached marshmallow-3.21.1-py3-none-any.whl (49 kB)
# Using cached multidict-6.0.5-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Downloading orjson-3.10.0-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.1/252.1 kB 14.2 MB/s eta 0:00:00
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached yarl-1.9.4-cp311-cp311-macosx_11_0_arm64.whl (81 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: urllib3, tenacity, SQLAlchemy, PyYAML, pydantic-core, packaging, orjson, numpy, mypy-extensions, multidict, jsonpointer, idna, frozenlist, charset-normalizer, certifi, attrs, annotated-types, yarl, typing-inspect, requests, pydantic, marshmallow, jsonpatch, aiosignal, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-community, langchain, langchain-experimental
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.29 aiohttp-3.9.3 aiosignal-1.3.1 annotated-types-0.6.0 attrs-23.2.0 certifi-2024.2.2 charset-normalizer-3.3.2 dataclasses-json-0.6.4 frozenlist-1.4.1 idna-3.7 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.15 langchain-community-0.0.32 langchain-core-0.1.41 langchain-experimental-0.0.57 langchain-text-splitters-0.0.1 langsmith-0.1.45 marshmallow-3.21.1 multidict-6.0.5 mypy-extensions-1.0.0 numpy-1.26.4 orjson-3.10.0 packaging-23.2 pydantic-2.6.4 pydantic-core-2.16.3 requests-2.31.0 tenacity-8.2.3 typing-inspect-0.9.0 urllib3-2.2.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tabulate
# %pip install pandas
# %pip install openai
# Out:
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from pandas) (2.9.0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp311-cp311-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 28.2 MB/s eta 0:00:0000:010:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting openai
#   Downloading openai-1.17.0-py3-none-any.whl.metadata (21 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from openai) (2.6.4)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/hanb/projects-langchain/ai-study/.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Downloading openai-1.17.0-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.3/268.3 kB 11.5 MB/s eta 0:00:00
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: tqdm, sniffio, h11, distro, httpcore, anyio, httpx, openai
# Successfully installed anyio-4.3.0 distro-1.9.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.17.0 sniffio-1.3.1 tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd # 파이썬 언어로 작성된 데이터를 분석 및 조작하기 위한 라이브러리

# csv 파일을 테이터프레임으로 가져오기 
df = pd.read_csv('../../datas/booksv_02.csv')
df.head()
# Out:
#             title subtitle                          authors  \
# 0          Gilead      NaN               Marilynne Robinson
# 1    Spider's Web  A Novel  Charles Osborne;Agatha Christie
# 2    The One Tree      NaN             Stephen R. Donaldson
# 3  Rage of angels      NaN                   Sidney Sheldon
# 4  The Four Loves      NaN              Clive Staples Lewis
#
#                       categories  \
# 0                        Fiction
# 1  Detective and mystery stories
# 2               American fiction
# 3                        Fiction
# 4                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# 3  http://books.google.com/books/content?id=FKo2T...
# 4  http://books.google.com/books/content?id=XhQ5X...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...            2004
# 1  A new 'Christie for Christmas' -- a full-lengt...            2000
# 2  Volume Two of Stephen Donaldson's acclaimed se...            1982
# 3  A memorable, mesmerizing heroine Jennifer -- b...            1993
# 4  Lewis' work on the nature of love divides love...            2002
#
#    average_rating  num_pages  ratings_count
# 0            3.85        247            361
# 1            3.83        241           5164
# 2            3.97        479            172
# 3            3.93        512          29532
# 4            4.15        170          33684

# %%
# %pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent
from langchain.chat_models import ChatOpenAI
from langchain.agents.agent_types import AgentType
from dotenv import load_dotenv
load_dotenv()

# 에이전트 생성
agent = create_pandas_dataframe_agent(
    ChatOpenAI(temperature=0, model='gpt-3.5-turbo-16k-0613'), # gpt-3.5-turbo
    df, # 데이터가 담긴 곳
    verbose=False, # 추론 과정을 출력하지 않음
    agent_type=AgentType.OPENAI_FUNCTIONS,
)

# %%
agent.run('어떤 제품의 ratings_count가 제일 높아?')
# Out:
# '제품 중에서 ratings_count가 가장 높은 책은 "One Hundred Years of Solitude"입니다.'

# %%
agent.run('가장 최근에 출간된 책은?')
# Out:
# '가장 최근에 출간된 책은 "The Yiddish Policemen\'s Union"입니다.'
